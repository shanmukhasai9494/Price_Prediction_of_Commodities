# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
url = 'https://drive.google.com/uc?id=1PzHpvKPanPPZPICHe19s8WCmdfJKbA2r'
data = pd.read_csv(url)

# %%
data.head()
# Out:
#            Crop  Crop_Year       Season  State     Area  Production
# 0      Arecanut       1997  Whole Year   Assam  73814.0       56708  \
# 1     Arhar/Tur       1997  Kharif       Assam   6637.0        4685
# 2   Castor seed       1997  Kharif       Assam    796.0          22
# 3      Coconut        1997  Whole Year   Assam  19656.0   126905000
# 4  Cotton(lint)       1997  Kharif       Assam   1739.0         794
#
#    Annual_Rainfall  Fertilizer  Pesticide        Yield
# 0           2051.4  7024878.38   22882.34     0.796087
# 1           2051.4   631643.29    2057.47     0.710435
# 2           2051.4    75755.32     246.76     0.238333
# 3           2051.4  1870661.52    6093.36  5238.051739
# 4           2051.4   165500.63     539.09     0.420909

# %%
data.shape
# Out:
# (19689, 10)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19689 entries, 0 to 19688
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Crop             19689 non-null  object
#  1   Crop_Year        19689 non-null  int64
#  2   Season           19689 non-null  object
#  3   State            19689 non-null  object
#  4   Area             19689 non-null  float64
#  5   Production       19689 non-null  int64
#  6   Annual_Rainfall  19689 non-null  float64
#  7   Fertilizer       19689 non-null  float64
#  8   Pesticide        19689 non-null  float64
#  9   Yield            19689 non-null  float64
# dtypes: float64(5), int64(2), object(3)
# memory usage: 1.5+ MB

# %%
data.isna().sum()
# Out:
# Crop               0
# Crop_Year          0
# Season             0
# State              0
# Area               0
# Production         0
# Annual_Rainfall    0
# Fertilizer         0
# Pesticide          0
# Yield              0
# dtype: int64

# %%
data.describe()
# Out:
#           Crop_Year          Area    Production  Annual_Rainfall
# count  19689.000000  1.968900e+04  1.968900e+04     19689.000000  \
# mean    2009.127584  1.799266e+05  1.643594e+07      1437.755177
# std        6.498099  7.328287e+05  2.630568e+08       816.909589
# min     1997.000000  5.000000e-01  0.000000e+00       301.300000
# 25%     2004.000000  1.390000e+03  1.393000e+03       940.700000
# 50%     2010.000000  9.317000e+03  1.380400e+04      1247.600000
# 75%     2015.000000  7.511200e+04  1.227180e+05      1643.700000
# max     2020.000000  5.080810e+07  6.326000e+09      6552.700000
#
#          Fertilizer     Pesticide         Yield
# count  1.968900e+04  1.968900e+04  19689.000000
# mean   2.410331e+07  4.884835e+04     79.954009
# std    9.494600e+07  2.132874e+05    878.306193
# min    5.417000e+01  9.000000e-02      0.000000
# 25%    1.880146e+05  3.567000e+02      0.600000
# 50%    1.234957e+06  2.421900e+03      1.030000
# 75%    1.000385e+07  2.004170e+04      2.388889
# max    4.835407e+09  1.575051e+07  21105.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def plot_outliers(data):
    """
    Plots box plots for each numerical column to visualize outliers.

    Args:
        data (pd.DataFrame): The DataFrame containing the numerical columns.
    """

    numerical_columns = data.select_dtypes(include=['int64', 'float64']).columns

    plt.figure(figsize=(15, 10))
    for i, column in enumerate(numerical_columns, 1):
        plt.subplot(3, 3, i)
        sns.boxplot(x=data[column])
        plt.title(f'Box Plot for {column}')

    plt.tight_layout()
    plt.show()

plot_outliers(data)

# %%
sns.set_style("white")

features_with_units = {
    'Area': 'Area (in hectares)',
    'Production': 'Production (in metric tons)',
    'Annual_Rainfall': 'Annual Rainfall (in mm)',
    'Fertilizer': 'Fertilizer (in kilograms)',
    'Pesticide': 'Pesticide (in kilograms)',
    'Crop_Year': 'Crop Year'
}

num_plots = len(features_with_units)
ncols = 2
nrows = (num_plots + 1) // ncols

fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(12, 12))
axes = axes.flatten()

for i, (feature, label) in enumerate(features_with_units.items()):
    sns.scatterplot(x=data[feature], y=data['Yield'], ax=axes[i], edgecolor= 'k')
    axes[i].set_title(f'Impact of {feature} on Yield')
    axes[i].set_xlabel(label)
    axes[i].set_ylabel('Yield')

plt.tight_layout(pad=3.0)
plt.subplots_adjust(hspace=0.4)
plt.show()

# %%
dark_pink = "#E75480"
plt.figure(figsize=(12, 6))
sns.boxplot(x='Crop', y='Yield', data=data, palette=[dark_pink])
plt.title("Yield Distribution Across Different Crops", fontsize=14)
plt.xlabel("Crop")
plt.ylabel("Yield")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import pandas as pd

numerical_columns = data.select_dtypes(include=["int64", "float64"]).columns

for column in numerical_columns:
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    data = data[(data[column] >= lower_bound) & (data[column] <= upper_bound)]

print(f"Data after outlier removal has {data.shape[0]} rows and {data.shape[1]} columns.")
# Out:
# Data after outlier removal has 8779 rows and 10 columns.

# %%
data['Fertilizer_per_Area'] = data['Fertilizer'] / data['Area']
data['Pesticide_per_Area'] = data['Pesticide'] / data['Area']

data_encoded = pd.get_dummies(data, columns=['Crop', 'Season', 'State'], drop_first=True)

print("New data shape after augmentation:", data.shape)
print("Encoded data shape:", data_encoded.shape)
print("\nSample of processed data:")
print(data_encoded.head())
# Out:
# New data shape after augmentation: (8779, 12)
# Encoded data shape: (8779, 97)
#
# Sample of processed data:
#    Crop_Year     Area  Production  Annual_Rainfall  Fertilizer  Pesticide
# 1       1997   6637.0        4685           2051.4   631643.29    2057.47  \
# 2       1997    796.0          22           2051.4    75755.32     246.76
# 4       1997   1739.0         794           2051.4   165500.63     539.09
# 5       1997  13587.0        9073           2051.4  1293074.79    4211.97
# 6       1997   2979.0        1507           2051.4   283511.43     923.49
#
#       Yield  Fertilizer_per_Area  Pesticide_per_Area  Crop_Arhar/Tur  ...
# 1  0.710435                95.17                0.31            True  ...  \
# 2  0.238333                95.17                0.31           False  ...
# 4  0.420909                95.17                0.31           False  ...
# 5  0.643636                95.17                0.31           False  ...
# 6  0.465455                95.17                0.31           False  ...
#
#    State_Odisha  State_Puducherry  State_Punjab  State_Sikkim
# 1         False             False         False         False  \
# 2         False             False         False         False
# 4         False             False         False         False
# 5         False             False         False         False
# 6         False             False         False         False
#
#    State_Tamil Nadu  State_Telangana  State_Tripura  State_Uttar Pradesh
# 1             False            False          False                False  \
# 2             False            False          False                False
# 4             False            False          False                False
# 5             False            False          False                False
# 6             False            False          False                False
#
#    State_Uttarakhand  State_West Bengal
# 1              False              False
# 2              False              False
# 4              False              False
# 5              False              False
# 6              False              False
#
# [5 rows x 97 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

X = data_encoded.drop('Yield', axis=1)
Y = data_encoded['Yield']

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

print(f"Training set shape: {X_train_scaled.shape}")
print(f"Test set shape: {X_test_scaled.shape}")
# Out:
# Training set shape: (7023, 96)
# Test set shape: (1756, 96)

# %%
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_squared_error

mlp_model = MLPRegressor(
    hidden_layer_sizes=(64, 32),
    max_iter=500,
    random_state=42,
    verbose=True,
    alpha = 0.0,
    tol=1e-5,
    n_iter_no_change=500
)
mlp_model.fit(X_train_scaled, Y_train)

Y_pred_mlp = mlp_model.predict(X_test_scaled)

mlp_mse = mean_squared_error(Y_test, Y_pred_mlp)
print(f"MLP Test MSE: {mlp_mse}")
# Out:
# Iteration 1, loss = 0.45937303
# Iteration 2, loss = 0.14925143
# Iteration 3, loss = 0.10499565
# Iteration 4, loss = 0.08699199
# Iteration 5, loss = 0.07590427
# Iteration 6, loss = 0.06739545
# Iteration 7, loss = 0.06134816
# Iteration 8, loss = 0.05640960
# Iteration 9, loss = 0.05313587
# Iteration 10, loss = 0.04925402
# Iteration 11, loss = 0.04700464
# Iteration 12, loss = 0.04484920
# Iteration 13, loss = 0.04313744
# Iteration 14, loss = 0.04139333
# Iteration 15, loss = 0.04094985
# Iteration 16, loss = 0.03875534
# Iteration 17, loss = 0.03747593
# Iteration 18, loss = 0.03647503
# Iteration 19, loss = 0.03563192
# Iteration 20, loss = 0.03497615
# Iteration 21, loss = 0.03426797
# Iteration 22, loss = 0.03450840
# Iteration 23, loss = 0.03318227
# Iteration 24, loss = 0.03284554
# Iteration 25, loss = 0.03190652
# Iteration 26, loss = 0.03120912
# Iteration 27, loss = 0.03045503
# Iteration 28, loss = 0.03065142
# Iteration 29, loss = 0.02949159
# Iteration 30, loss = 0.02919275
# Iteration 31, loss = 0.02886142
# Iteration 32, loss = 0.03052107
# Iteration 33, loss = 0.02782052
# Iteration 34, loss = 0.02862867
# Iteration 35, loss = 0.02819061
# Iteration 36, loss = 0.02738250
# Iteration 37, loss = 0.02707647
# Iteration 38, loss = 0.02706359
# Iteration 39, loss = 0.02814260
# Iteration 40, loss = 0.02666097
# Iteration 41, loss = 0.02618173
# Iteration 42, loss = 0.02822754
# Iteration 43, loss = 0.02656275
# Iteration 44, loss = 0.02633035
# Iteration 45, loss = 0.02519277
# Iteration 46, loss = 0.02530673
# Iteration 47, loss = 0.02495997
# Iteration 48, loss = 0.02438242
# Iteration 49, loss = 0.02405834
# Iteration 50, loss = 0.02418785
# Iteration 51, loss = 0.02448049
# Iteration 52, loss = 0.02382259
# Iteration 53, loss = 0.02313354
# Iteration 54, loss = 0.02426843
# Iteration 55, loss = 0.02347921
# Iteration 56, loss = 0.02384827
# Iteration 57, loss = 0.02255143
# Iteration 58, loss = 0.02278309
# Iteration 59, loss = 0.02221688
# Iteration 60, loss = 0.02304834
# Iteration 61, loss = 0.02281247
# Iteration 62, loss = 0.02224841
# Iteration 63, loss = 0.02184129
# Iteration 64, loss = 0.02177741
# Iteration 65, loss = 0.02163943
# Iteration 66, loss = 0.02313558
# Iteration 67, loss = 0.02187059
# Iteration 68, loss = 0.02121524
# Iteration 69, loss = 0.02179592
# Iteration 70, loss = 0.02085333
# Iteration 71, loss = 0.02259027
# Iteration 72, loss = 0.02107873
# Iteration 73, loss = 0.02097935
# Iteration 74, loss = 0.02027619
# Iteration 75, loss = 0.02088084
# Iteration 76, loss = 0.02096432
# Iteration 77, loss = 0.02215070
# Iteration 78, loss = 0.02155892
# Iteration 79, loss = 0.02030261
# Iteration 80, loss = 0.02025575
# Iteration 81, loss = 0.02022478
# Iteration 82, loss = 0.02007836
# Iteration 83, loss = 0.01903856
# Iteration 84, loss = 0.01922268
# Iteration 85, loss = 0.01991240
# Iteration 86, loss = 0.01923014
# Iteration 87, loss = 0.01928593
# Iteration 88, loss = 0.01871978
# Iteration 89, loss = 0.01862318
# Iteration 90, loss = 0.01932472
# Iteration 91, loss = 0.01909958
# Iteration 92, loss = 0.01837738
# Iteration 93, loss = 0.01944058
# Iteration 94, loss = 0.01836642
# Iteration 95, loss = 0.01855019
# Iteration 96, loss = 0.01846275
# Iteration 97, loss = 0.01946513
# Iteration 98, loss = 0.02105757
# Iteration 99, loss = 0.01959149
# Iteration 100, loss = 0.01905004
# Iteration 101, loss = 0.01900111
# Iteration 102, loss = 0.01936951
# Iteration 103, loss = 0.01818904
# Iteration 104, loss = 0.01850988
# Iteration 105, loss = 0.01808687
# Iteration 106, loss = 0.01814517
# Iteration 107, loss = 0.01732613
# Iteration 108, loss = 0.01889806
# Iteration 109, loss = 0.01886015
# Iteration 110, loss = 0.01776547
# Iteration 111, loss = 0.01761319
# Iteration 112, loss = 0.01767478
# Iteration 113, loss = 0.01729231
# Iteration 114, loss = 0.01770356
# Iteration 115, loss = 0.01804326
# Iteration 116, loss = 0.01866433
# Iteration 117, loss = 0.01758962
# Iteration 118, loss = 0.01751933
# Iteration 119, loss = 0.01832450
# Iteration 120, loss = 0.01701345
# Iteration 121, loss = 0.01666506
# Iteration 122, loss = 0.01670404
# Iteration 123, loss = 0.01638160
# Iteration 124, loss = 0.01687656
# Iteration 125, loss = 0.01646547
# Iteration 126, loss = 0.01603129
# Iteration 127, loss = 0.01598669
# Iteration 128, loss = 0.01605394
# Iteration 129, loss = 0.01657539
# Iteration 130, loss = 0.01673123
# Iteration 131, loss = 0.01622838
# Iteration 132, loss = 0.01659101
# Iteration 133, loss = 0.01720433
# Iteration 134, loss = 0.01680232
# Iteration 135, loss = 0.01589476
# Iteration 136, loss = 0.01681846
# Iteration 137, loss = 0.01628717
# Iteration 138, loss = 0.01608525
# Iteration 139, loss = 0.01618738
# Iteration 140, loss = 0.01703354
# Iteration 141, loss = 0.01568389
# Iteration 142, loss = 0.01562675
# Iteration 143, loss = 0.01569632
# Iteration 144, loss = 0.01544781
# Iteration 145, loss = 0.01822858
# Iteration 146, loss = 0.01607113
# Iteration 147, loss = 0.01560624
# Iteration 148, loss = 0.01526854
# Iteration 149, loss = 0.01510190
# Iteration 150, loss = 0.01506476
# Iteration 151, loss = 0.01613632
# Iteration 152, loss = 0.01492296
# Iteration 153, loss = 0.01812282
# Iteration 154, loss = 0.01532733
# Iteration 155, loss = 0.01518469
# Iteration 156, loss = 0.01543500
# Iteration 157, loss = 0.01612921
# Iteration 158, loss = 0.01578358
# Iteration 159, loss = 0.01515088
# Iteration 160, loss = 0.01622028
# Iteration 161, loss = 0.01565731
# Iteration 162, loss = 0.01532230
# Iteration 163, loss = 0.01550145
# Iteration 164, loss = 0.01479338
# Iteration 165, loss = 0.01531798
# Iteration 166, loss = 0.01502330
# Iteration 167, loss = 0.01444971
# Iteration 168, loss = 0.01453779
# Iteration 169, loss = 0.01473061
# Iteration 170, loss = 0.01428200
# Iteration 171, loss = 0.01414134
# Iteration 172, loss = 0.01404966
# Iteration 173, loss = 0.01388284
# Iteration 174, loss = 0.01471853
# Iteration 175, loss = 0.01466366
# Iteration 176, loss = 0.01520614
# Iteration 177, loss = 0.01417727
# Iteration 178, loss = 0.01395824
# Iteration 179, loss = 0.01451884
# Iteration 180, loss = 0.01396442
# Iteration 181, loss = 0.01503694
# Iteration 182, loss = 0.01572330
# Iteration 183, loss = 0.01426231
# Iteration 184, loss = 0.01493077
# Iteration 185, loss = 0.01654891
# Iteration 186, loss = 0.01461234
# Iteration 187, loss = 0.01432552
# Iteration 188, loss = 0.01340531
# Iteration 189, loss = 0.01358872
# Iteration 190, loss = 0.01350281
# Iteration 191, loss = 0.01362175
# Iteration 192, loss = 0.01378801
# Iteration 193, loss = 0.01412886
# Iteration 194, loss = 0.01412518
# Iteration 195, loss = 0.01336236
# Iteration 196, loss = 0.01340622
# Iteration 197, loss = 0.01401607
# Iteration 198, loss = 0.01366874
# Iteration 199, loss = 0.01476726
# Iteration 200, loss = 0.01378588
# Iteration 201, loss = 0.01414454
# Iteration 202, loss = 0.01328016
# Iteration 203, loss = 0.01346247
# Iteration 204, loss = 0.01359952
# Iteration 205, loss = 0.01328349
# Iteration 206, loss = 0.01553362
# Iteration 207, loss = 0.01336675
# Iteration 208, loss = 0.01338100
# Iteration 209, loss = 0.01500464
# Iteration 210, loss = 0.01343010
# Iteration 211, loss = 0.01299363
# Iteration 212, loss = 0.01440566
# Iteration 213, loss = 0.01359861
# Iteration 214, loss = 0.01354424
# Iteration 215, loss = 0.01410686
# Iteration 216, loss = 0.01302691
# Iteration 217, loss = 0.01296131
# Iteration 218, loss = 0.01303922
# Iteration 219, loss = 0.01300785
# Iteration 220, loss = 0.01276753
# Iteration 221, loss = 0.01239809
# Iteration 222, loss = 0.01350284
# Iteration 223, loss = 0.01300754
# Iteration 224, loss = 0.01360561
# Iteration 225, loss = 0.01269350
# Iteration 226, loss = 0.01237232
# Iteration 227, loss = 0.01219558
# Iteration 228, loss = 0.01321793
# Iteration 229, loss = 0.01265962
# Iteration 230, loss = 0.01373882
# Iteration 231, loss = 0.01340860
# Iteration 232, loss = 0.01427375
# Iteration 233, loss = 0.01330818
# Iteration 234, loss = 0.01290973
# Iteration 235, loss = 0.01279841
# Iteration 236, loss = 0.01332841
# Iteration 237, loss = 0.01364711
# Iteration 238, loss = 0.01311464
# Iteration 239, loss = 0.01230881
# Iteration 240, loss = 0.01240534
# Iteration 241, loss = 0.01228175
# Iteration 242, loss = 0.01199797
# Iteration 243, loss = 0.01166018
# Iteration 244, loss = 0.01305324
# Iteration 245, loss = 0.01262769
# Iteration 246, loss = 0.01216754
# Iteration 247, loss = 0.01189114
# Iteration 248, loss = 0.01235055
# Iteration 249, loss = 0.01196781
# Iteration 250, loss = 0.01229280
# Iteration 251, loss = 0.01223776
# Iteration 252, loss = 0.01209297
# Iteration 253, loss = 0.01211091
# Iteration 254, loss = 0.01264027
# Iteration 255, loss = 0.01239123
# Iteration 256, loss = 0.01173547
# Iteration 257, loss = 0.01288991
# Iteration 258, loss = 0.01382357
# Iteration 259, loss = 0.01345007
# Iteration 260, loss = 0.01217207
# Iteration 261, loss = 0.01284849
# Iteration 262, loss = 0.01222167
# Iteration 263, loss = 0.01272530
# Iteration 264, loss = 0.01319028
# Iteration 265, loss = 0.01177448
# Iteration 266, loss = 0.01204669
# Iteration 267, loss = 0.01166571
# Iteration 268, loss = 0.01119975
# Iteration 269, loss = 0.01240579
# Iteration 270, loss = 0.01280167
# Iteration 271, loss = 0.01206450
# Iteration 272, loss = 0.01206434
# Iteration 273, loss = 0.01227915
# Iteration 274, loss = 0.01215404
# Iteration 275, loss = 0.01197510
# Iteration 276, loss = 0.01175098
# Iteration 277, loss = 0.01256434
# Iteration 278, loss = 0.01177316
# Iteration 279, loss = 0.01174676
# Iteration 280, loss = 0.01134348
# Iteration 281, loss = 0.01125360
# Iteration 282, loss = 0.01100472
# Iteration 283, loss = 0.01152738
# Iteration 284, loss = 0.01252581
# Iteration 285, loss = 0.01126913
# Iteration 286, loss = 0.01187754
# Iteration 287, loss = 0.01185571
# Iteration 288, loss = 0.01191172
# Iteration 289, loss = 0.01211768
# Iteration 290, loss = 0.01138549
# Iteration 291, loss = 0.01127351
# Iteration 292, loss = 0.01151228
# Iteration 293, loss = 0.01392807
# Iteration 294, loss = 0.01217840
# Iteration 295, loss = 0.01202154
# Iteration 296, loss = 0.01107450
# Iteration 297, loss = 0.01156281
# Iteration 298, loss = 0.01234615
# Iteration 299, loss = 0.01180666
# Iteration 300, loss = 0.01075068
# Iteration 301, loss = 0.01068918
# Iteration 302, loss = 0.01086233
# Iteration 303, loss = 0.01066314
# Iteration 304, loss = 0.01065651
# Iteration 305, loss = 0.01407978
# Iteration 306, loss = 0.01284416
# Iteration 307, loss = 0.01382827
# Iteration 308, loss = 0.01131448
# Iteration 309, loss = 0.01069025
# Iteration 310, loss = 0.01127640
# Iteration 311, loss = 0.01232085
# Iteration 312, loss = 0.01106462
# Iteration 313, loss = 0.01082062
# Iteration 314, loss = 0.01196563
# Iteration 315, loss = 0.01148977
# Iteration 316, loss = 0.01068672
# Iteration 317, loss = 0.01053104
# Iteration 318, loss = 0.01104255
# Iteration 319, loss = 0.01179413
# Iteration 320, loss = 0.01115813
# Iteration 321, loss = 0.01180101
# Iteration 322, loss = 0.01098683
# Iteration 323, loss = 0.01091700
# Iteration 324, loss = 0.01111432
# Iteration 325, loss = 0.01084262
# Iteration 326, loss = 0.01052899
# Iteration 327, loss = 0.01030943
# Iteration 328, loss = 0.01043102
# Iteration 329, loss = 0.01055449
# Iteration 330, loss = 0.01049344
# Iteration 331, loss = 0.01028008
# Iteration 332, loss = 0.01042358
# Iteration 333, loss = 0.01019758
# Iteration 334, loss = 0.01021945
# Iteration 335, loss = 0.01032560
# Iteration 336, loss = 0.01242133
# Iteration 337, loss = 0.01166355
# Iteration 338, loss = 0.01073960
# Iteration 339, loss = 0.01065299
# Iteration 340, loss = 0.01019414
# Iteration 341, loss = 0.01113693
# Iteration 342, loss = 0.01013173
# Iteration 343, loss = 0.01010163
# Iteration 344, loss = 0.01091322
# Iteration 345, loss = 0.01094320
# Iteration 346, loss = 0.01013917
# Iteration 347, loss = 0.01020480
# Iteration 348, loss = 0.01004269
# Iteration 349, loss = 0.01000417
# Iteration 350, loss = 0.01005785
# Iteration 351, loss = 0.01050998
# Iteration 352, loss = 0.00978322
# Iteration 353, loss = 0.01015723
# Iteration 354, loss = 0.00994704
# Iteration 355, loss = 0.01017065
# Iteration 356, loss = 0.01009235
# Iteration 357, loss = 0.01034467
# Iteration 358, loss = 0.00984491
# Iteration 359, loss = 0.01030328
# Iteration 360, loss = 0.00973503
# Iteration 361, loss = 0.01051610
# Iteration 362, loss = 0.01050306
# Iteration 363, loss = 0.01039358
# Iteration 364, loss = 0.01020048
# Iteration 365, loss = 0.00977880
# Iteration 366, loss = 0.00996904
# Iteration 367, loss = 0.00967343
# Iteration 368, loss = 0.01013964
# Iteration 369, loss = 0.00962644
# Iteration 370, loss = 0.00969407
# Iteration 371, loss = 0.01043258
# Iteration 372, loss = 0.00991511
# Iteration 373, loss = 0.01144578
# Iteration 374, loss = 0.01037520
# Iteration 375, loss = 0.01030793
# Iteration 376, loss = 0.01050870
# Iteration 377, loss = 0.01052294
# Iteration 378, loss = 0.01069783
# Iteration 379, loss = 0.01144847
# Iteration 380, loss = 0.01002449
# Iteration 381, loss = 0.00962043
# Iteration 382, loss = 0.00916666
# Iteration 383, loss = 0.00939972
# Iteration 384, loss = 0.00985454
# Iteration 385, loss = 0.01055203
# Iteration 386, loss = 0.00976169
# Iteration 387, loss = 0.00945021
# Iteration 388, loss = 0.00952184
# Iteration 389, loss = 0.00945017
# Iteration 390, loss = 0.00944107
# Iteration 391, loss = 0.00955170
# Iteration 392, loss = 0.00960842
# Iteration 393, loss = 0.00969655
# Iteration 394, loss = 0.00930565
# Iteration 395, loss = 0.01009223
# Iteration 396, loss = 0.01003614
# Iteration 397, loss = 0.00997590
# Iteration 398, loss = 0.01021483
# Iteration 399, loss = 0.00989367
# Iteration 400, loss = 0.00967373
# Iteration 401, loss = 0.00945206
# Iteration 402, loss = 0.00922285
# Iteration 403, loss = 0.00980835
# Iteration 404, loss = 0.00924907
# Iteration 405, loss = 0.00966220
# Iteration 406, loss = 0.01013547
# Iteration 407, loss = 0.00992335
# Iteration 408, loss = 0.01093070
# Iteration 409, loss = 0.00957889
# Iteration 410, loss = 0.00984879
# Iteration 411, loss = 0.00972149
# Iteration 412, loss = 0.01019328
# Iteration 413, loss = 0.00993272
# Iteration 414, loss = 0.00981544
# Iteration 415, loss = 0.00921030
# Iteration 416, loss = 0.00899278
# Iteration 417, loss = 0.01038474
# Iteration 418, loss = 0.00929604
# Iteration 419, loss = 0.00950656
# Iteration 420, loss = 0.00928631
# Iteration 421, loss = 0.00977747
# Iteration 422, loss = 0.00998609
# Iteration 423, loss = 0.00936651
# Iteration 424, loss = 0.00909850
# Iteration 425, loss = 0.00901653
# Iteration 426, loss = 0.00907449
# Iteration 427, loss = 0.01008263
# Iteration 428, loss = 0.00999738
# Iteration 429, loss = 0.00962355
# Iteration 430, loss = 0.00907973
# Iteration 431, loss = 0.00949600
# Iteration 432, loss = 0.00935505
# Iteration 433, loss = 0.00922346
# Iteration 434, loss = 0.00883399
# Iteration 435, loss = 0.00889124
# Iteration 436, loss = 0.00916111
# Iteration 437, loss = 0.01029114
# Iteration 438, loss = 0.01044485
# Iteration 439, loss = 0.00942250
# Iteration 440, loss = 0.00892993
# Iteration 441, loss = 0.00951702
# Iteration 442, loss = 0.00949836
# Iteration 443, loss = 0.00950139
# Iteration 444, loss = 0.00931135
# Iteration 445, loss = 0.00918867
# Iteration 446, loss = 0.00918912
# Iteration 447, loss = 0.00900278
# Iteration 448, loss = 0.00963990
# Iteration 449, loss = 0.00969816
# Iteration 450, loss = 0.00875213
# Iteration 451, loss = 0.00884136
# Iteration 452, loss = 0.00855268
# Iteration 453, loss = 0.00850784
# Iteration 454, loss = 0.00869880
# Iteration 455, loss = 0.00825144
# Iteration 456, loss = 0.00858166
# Iteration 457, loss = 0.00863692
# Iteration 458, loss = 0.00836461
# Iteration 459, loss = 0.00861370
# Iteration 460, loss = 0.00938080
# Iteration 461, loss = 0.00884408
# Iteration 462, loss = 0.00838695
# Iteration 463, loss = 0.01014510
# Iteration 464, loss = 0.01088242
# Iteration 465, loss = 0.00929238
# Iteration 466, loss = 0.00943135
# Iteration 467, loss = 0.00924563
# Iteration 468, loss = 0.01030070
# Iteration 469, loss = 0.00940519
# Iteration 470, loss = 0.00877853
# Iteration 471, loss = 0.00839263
# Iteration 472, loss = 0.00842087
# Iteration 473, loss = 0.00895555
# Iteration 474, loss = 0.00883251
# Iteration 475, loss = 0.00870940
# Iteration 476, loss = 0.00925889
# Iteration 477, loss = 0.00836876
# Iteration 478, loss = 0.00878241
# Iteration 479, loss = 0.00914634
# Iteration 480, loss = 0.00885646
# Iteration 481, loss = 0.00870758
# Iteration 482, loss = 0.00907359
# Iteration 483, loss = 0.00848389
# Iteration 484, loss = 0.00977200
# Iteration 485, loss = 0.00897319
# Iteration 486, loss = 0.00829904
# Iteration 487, loss = 0.00839403
# Iteration 488, loss = 0.00909486
# Iteration 489, loss = 0.00916553
# Iteration 490, loss = 0.00906388
# Iteration 491, loss = 0.00863945
# Iteration 492, loss = 0.00859744
# Iteration 493, loss = 0.00854192
# Iteration 494, loss = 0.00827988
# Iteration 495, loss = 0.00961085
# Iteration 496, loss = 0.00828269
# Iteration 497, loss = 0.01126872
# Iteration 498, loss = 0.00848317
# Iteration 499, loss = 0.00854431
# Iteration 500, loss = 0.00811166
# MLP Test MSE: 0.0848270565875803

# %%
mlp_model_reg = MLPRegressor(hidden_layer_sizes=(64, 32),
                             alpha=0.01,
                             max_iter=500,
                             random_state=42,
                             verbose =True,
                             tol=1e-5,
                             early_stopping=True,
                             validation_fraction=0.1,
                             n_iter_no_change=10,
                            )
mlp_model_reg.fit(X_train_scaled, Y_train)
Y_pred_mlp_reg = mlp_model_reg.predict(X_test_scaled)
# Out:
# Iteration 1, loss = 0.48706581
# Validation score: 0.183073
# Iteration 2, loss = 0.16432840
# Validation score: 0.484279
# Iteration 3, loss = 0.11432860
# Validation score: 0.584782
# Iteration 4, loss = 0.09376109
# Validation score: 0.637960
# Iteration 5, loss = 0.08169637
# Validation score: 0.672162
# Iteration 6, loss = 0.07284276
# Validation score: 0.695661
# Iteration 7, loss = 0.06633501
# Validation score: 0.718776
# Iteration 8, loss = 0.06133709
# Validation score: 0.737030
# Iteration 9, loss = 0.05745963
# Validation score: 0.749950
# Iteration 10, loss = 0.05424945
# Validation score: 0.759351
# Iteration 11, loss = 0.05112400
# Validation score: 0.767153
# Iteration 12, loss = 0.04874746
# Validation score: 0.776938
# Iteration 13, loss = 0.04716709
# Validation score: 0.776911
# Iteration 14, loss = 0.04509932
# Validation score: 0.786999
# Iteration 15, loss = 0.04367771
# Validation score: 0.791012
# Iteration 16, loss = 0.04232881
# Validation score: 0.794228
# Iteration 17, loss = 0.04132260
# Validation score: 0.799346
# Iteration 18, loss = 0.03978575
# Validation score: 0.803124
# Iteration 19, loss = 0.03933888
# Validation score: 0.802543
# Iteration 20, loss = 0.03791774
# Validation score: 0.804270
# Iteration 21, loss = 0.03707860
# Validation score: 0.806023
# Iteration 22, loss = 0.03654006
# Validation score: 0.809451
# Iteration 23, loss = 0.03640738
# Validation score: 0.808820
# Iteration 24, loss = 0.03526630
# Validation score: 0.809960
# Iteration 25, loss = 0.03457383
# Validation score: 0.811201
# Iteration 26, loss = 0.03374733
# Validation score: 0.816641
# Iteration 27, loss = 0.03337223
# Validation score: 0.813149
# Iteration 28, loss = 0.03302437
# Validation score: 0.814648
# Iteration 29, loss = 0.03268254
# Validation score: 0.818017
# Iteration 30, loss = 0.03237278
# Validation score: 0.815289
# Iteration 31, loss = 0.03165502
# Validation score: 0.820081
# Iteration 32, loss = 0.03096995
# Validation score: 0.819405
# Iteration 33, loss = 0.03087302
# Validation score: 0.820838
# Iteration 34, loss = 0.03055657
# Validation score: 0.823118
# Iteration 35, loss = 0.02987769
# Validation score: 0.819807
# Iteration 36, loss = 0.02993983
# Validation score: 0.824762
# Iteration 37, loss = 0.03004346
# Validation score: 0.825814
# Iteration 38, loss = 0.03045245
# Validation score: 0.827416
# Iteration 39, loss = 0.02999616
# Validation score: 0.824369
# Iteration 40, loss = 0.02950608
# Validation score: 0.823392
# Iteration 41, loss = 0.02934967
# Validation score: 0.825588
# Iteration 42, loss = 0.02871415
# Validation score: 0.825692
# Iteration 43, loss = 0.02857848
# Validation score: 0.824776
# Iteration 44, loss = 0.02885786
# Validation score: 0.822337
# Iteration 45, loss = 0.02797228
# Validation score: 0.828412
# Iteration 46, loss = 0.02769871
# Validation score: 0.824741
# Iteration 47, loss = 0.02733428
# Validation score: 0.829416
# Iteration 48, loss = 0.02702575
# Validation score: 0.827675
# Iteration 49, loss = 0.02739586
# Validation score: 0.826607
# Iteration 50, loss = 0.02666666
# Validation score: 0.829678
# Iteration 51, loss = 0.02626193
# Validation score: 0.831986
# Iteration 52, loss = 0.02642074
# Validation score: 0.832979
# Iteration 53, loss = 0.02617858
# Validation score: 0.834297
# Iteration 54, loss = 0.02587180
# Validation score: 0.832461
# Iteration 55, loss = 0.02526548
# Validation score: 0.833664
# Iteration 56, loss = 0.02576376
# Validation score: 0.833330
# Iteration 57, loss = 0.02544576
# Validation score: 0.832830
# Iteration 58, loss = 0.02636880
# Validation score: 0.823730
# Iteration 59, loss = 0.02607436
# Validation score: 0.830733
# Iteration 60, loss = 0.02594175
# Validation score: 0.828958
# Iteration 61, loss = 0.02488987
# Validation score: 0.833216
# Iteration 62, loss = 0.02496922
# Validation score: 0.836006
# Iteration 63, loss = 0.02464202
# Validation score: 0.833052
# Iteration 64, loss = 0.02383714
# Validation score: 0.832465
# Iteration 65, loss = 0.02398382
# Validation score: 0.836733
# Iteration 66, loss = 0.02408867
# Validation score: 0.833556
# Iteration 67, loss = 0.02386219
# Validation score: 0.834033
# Iteration 68, loss = 0.02386770
# Validation score: 0.835890
# Iteration 69, loss = 0.02346385
# Validation score: 0.830777
# Iteration 70, loss = 0.02368968
# Validation score: 0.836204
# Iteration 71, loss = 0.02370007
# Validation score: 0.833529
# Iteration 72, loss = 0.02382241
# Validation score: 0.831539
# Iteration 73, loss = 0.02351188
# Validation score: 0.831140
# Iteration 74, loss = 0.02394158
# Validation score: 0.835456
# Iteration 75, loss = 0.02333131
# Validation score: 0.836927
# Iteration 76, loss = 0.02328205
# Validation score: 0.835289
# Iteration 77, loss = 0.02334007
# Validation score: 0.835327
# Iteration 78, loss = 0.02311893
# Validation score: 0.835352
# Iteration 79, loss = 0.02292166
# Validation score: 0.836549
# Iteration 80, loss = 0.02247479
# Validation score: 0.833540
# Iteration 81, loss = 0.02236359
# Validation score: 0.828976
# Iteration 82, loss = 0.02284550
# Validation score: 0.830472
# Iteration 83, loss = 0.02249718
# Validation score: 0.834548
# Iteration 84, loss = 0.02217991
# Validation score: 0.832320
# Iteration 85, loss = 0.02218204
# Validation score: 0.835546
# Iteration 86, loss = 0.02213554
# Validation score: 0.833662
# Validation score did not improve more than tol=0.000010 for 10 consecutive epochs. Stopping.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Flatten, Dense, Dropout, BatchNormalization, GlobalAveragePooling1D

def create_cnn_model(input_shape):
    model = Sequential([
        Conv1D(64, kernel_size=3, activation='relu', input_shape=(input_shape, 1)),
        BatchNormalization(),
        Conv1D(128, kernel_size=3, activation='relu'),
        Dropout(0.3),
        BatchNormalization(),
        GlobalAveragePooling1D(),
        Dense(128, activation='relu'),
        Dropout(0.2),
        Dense(64, activation='relu'),
        Dense(1)
    ])
    return model
# Out:
# WARNING:tensorflow:From c:\Users\saidi\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
X_train_cnn = X_train_scaled.reshape(X_train_scaled.shape[0], X_train_scaled.shape[1], 1)
X_test_cnn = X_test_scaled.reshape(X_test_scaled.shape[0], X_test_scaled.shape[1], 1)

cnn_model = create_cnn_model(X_train_scaled.shape[1])
cnn_model.compile(optimizer='adam', loss='mse', metrics=['mae'])

history = cnn_model.fit(
    X_train_cnn,
    Y_train,
    validation_split=0.2,
    epochs=50,
    batch_size=32,
    verbose=1
)
Y_pred_cnn = cnn_model.predict(X_test_cnn)
# Out:
# WARNING:tensorflow:From c:\Users\saidi\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\saidi\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/50
# WARNING:tensorflow:From c:\Users\saidi\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\saidi\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 176/176 [==============================] - 4s 11ms/step - loss: 0.5405 - mae: 0.5357 - val_loss: 0.7435 - val_mae: 0.7675
# Epoch 2/50
# 176/176 [==============================] - 2s 12ms/step - loss: 0.4326 - mae: 0.4863 - val_loss: 0.4826 - val_mae: 0.5458
# Epoch 3/50
# 176/176 [==============================] - 2s 12ms/step - loss: 0.3985 - mae: 0.4612 - val_loss: 0.4420 - val_mae: 0.5153
# Epoch 4/50
# 176/176 [==============================] - 2s 12ms/step - loss: 0.3747 - mae: 0.4462 - val_loss: 0.4260 - val_mae: 0.4975
# Epoch 5/50
# 176/176 [==============================] - 2s 12ms/step - loss: 0.3636 - mae: 0.4356 - val_loss: 0.4124 - val_mae: 0.4500
# Epoch 6/50
# 176/176 [==============================] - 2s 13ms/step - loss: 0.3433 - mae: 0.4221 - val_loss: 0.3598 - val_mae: 0.4252
# Epoch 7/50
# 176/176 [==============================] - 2s 12ms/step - loss: 0.3307 - mae: 0.4156 - val_loss: 0.6247 - val_mae: 0.5536
# Epoch 8/50
# 176/176 [==============================] - 2s 13ms/step - loss: 0.3218 - mae: 0.4086 - val_loss: 0.5556 - val_mae: 0.5162
# Epoch 9/50
# 176/176 [==============================] - 2s 13ms/step - loss: 0.3144 - mae: 0.4049 - val_loss: 0.3661 - val_mae: 0.4053
# Epoch 10/50
# 176/176 [==============================] - 2s 12ms/step - loss: 0.3102 - mae: 0.3972 - val_loss: 0.3170 - val_mae: 0.3676
# Epoch 11/50
# 176/176 [==============================] - 2s 12ms/step - loss: 0.2958 - mae: 0.3913 - val_loss: 0.2873 - val_mae: 0.3847
# Epoch 12/50
# 176/176 [==============================] - 2s 12ms/step - loss: 0.2901 - mae: 0.3830 - val_loss: 0.2781 - val_mae: 0.3865
# Epoch 13/50
# 176/176 [==============================] - 2s 12ms/step - loss: 0.2864 - mae: 0.3820 - val_loss: 0.3035 - val_mae: 0.4173
# Epoch 14/50
# 176/176 [==============================] - 2s 12ms/step - loss: 0.2782 - mae: 0.3738 - val_loss: 0.4171 - val_mae: 0.5259
# Epoch 15/50
# 176/176 [==============================] - 2s 12ms/step - loss: 0.2678 - mae: 0.3657 - val_loss: 0.3906 - val_mae: 0.5147
# Epoch 16/50
# 176/176 [==============================] - 2s 11ms/step - loss: 0.2725 - mae: 0.3708 - val_loss: 0.2514 - val_mae: 0.3609
# Epoch 17/50
# 176/176 [==============================] - 2s 11ms/step - loss: 0.2692 - mae: 0.3655 - val_loss: 0.3329 - val_mae: 0.4496
# Epoch 18/50
# 176/176 [==============================] - 2s 11ms/step - loss: 0.2616 - mae: 0.3639 - val_loss: 0.2864 - val_mae: 0.4140
# Epoch 19/50
# 176/176 [==============================] - 2s 12ms/step - loss: 0.2610 - mae: 0.3589 - val_loss: 0.2356 - val_mae: 0.3371
# Epoch 20/50
# 176/176 [==============================] - 2s 12ms/step - loss: 0.2600 - mae: 0.3597 - val_loss: 0.2485 - val_mae: 0.3454
# Epoch 21/50
# 176/176 [==============================] - 2s 12ms/step - loss: 0.2551 - mae: 0.3531 - val_loss: 0.2580 - val_mae: 0.3758
# Epoch 22/50
# 176/176 [==============================] - 4s 20ms/step - loss: 0.2485 - mae: 0.3486 - val_loss: 0.2624 - val_mae: 0.3524
# Epoch 23/50
# 176/176 [==============================] - 8s 46ms/step - loss: 0.2420 - mae: 0.3436 - val_loss: 0.2328 - val_mae: 0.3302
# Epoch 24/50
# 176/176 [==============================] - 5s 27ms/step - loss: 0.2380 - mae: 0.3414 - val_loss: 0.3208 - val_mae: 0.3763
# Epoch 25/50
# 176/176 [==============================] - 9s 53ms/step - loss: 0.2368 - mae: 0.3392 - val_loss: 0.2287 - val_mae: 0.3221
# Epoch 26/50
# 176/176 [==============================] - 2s 12ms/step - loss: 0.2396 - mae: 0.3386 - val_loss: 0.3477 - val_mae: 0.3858
# Epoch 27/50
# 176/176 [==============================] - 2s 11ms/step - loss: 0.2314 - mae: 0.3341 - val_loss: 0.2311 - val_mae: 0.3158
# Epoch 28/50
# 176/176 [==============================] - 2s 11ms/step - loss: 0.2311 - mae: 0.3336 - val_loss: 0.2321 - val_mae: 0.2987
# Epoch 29/50
# 176/176 [==============================] - 2s 11ms/step - loss: 0.2207 - mae: 0.3262 - val_loss: 0.2200 - val_mae: 0.3186
# Epoch 30/50
# 176/176 [==============================] - 2s 12ms/step - loss: 0.2187 - mae: 0.3240 - val_loss: 0.2319 - val_mae: 0.3267
# Epoch 31/50
# 176/176 [==============================] - 2s 11ms/step - loss: 0.2223 - mae: 0.3269 - val_loss: 0.1994 - val_mae: 0.2901
# Epoch 32/50
# 176/176 [==============================] - 2s 12ms/step - loss: 0.2182 - mae: 0.3203 - val_loss: 0.2631 - val_mae: 0.3236
# Epoch 33/50
# 176/176 [==============================] - 2s 12ms/step - loss: 0.2168 - mae: 0.3207 - val_loss: 0.3253 - val_mae: 0.3842
# Epoch 34/50
# 176/176 [==============================] - 2s 12ms/step - loss: 0.2157 - mae: 0.3197 - val_loss: 0.1833 - val_mae: 0.2843
# Epoch 35/50
# 176/176 [==============================] - 2s 12ms/step - loss: 0.2153 - mae: 0.3224 - val_loss: 0.2629 - val_mae: 0.3178
# Epoch 36/50
# 176/176 [==============================] - 2s 11ms/step - loss: 0.2123 - mae: 0.3168 - val_loss: 0.2029 - val_mae: 0.2900
# Epoch 37/50
# 176/176 [==============================] - 2s 11ms/step - loss: 0.2064 - mae: 0.3138 - val_loss: 0.1863 - val_mae: 0.2902
# Epoch 38/50
# 176/176 [==============================] - 2s 11ms/step - loss: 0.2028 - mae: 0.3104 - val_loss: 0.1868 - val_mae: 0.2974
# Epoch 39/50
# 176/176 [==============================] - 2s 11ms/step - loss: 0.2051 - mae: 0.3099 - val_loss: 0.2709 - val_mae: 0.3516
# Epoch 40/50
# 176/176 [==============================] - 2s 12ms/step - loss: 0.2106 - mae: 0.3149 - val_loss: 0.2273 - val_mae: 0.3055
# Epoch 41/50
# 176/176 [==============================] - 2s 11ms/step - loss: 0.2031 - mae: 0.3094 - val_loss: 0.1942 - val_mae: 0.2991
# Epoch 42/50
# 176/176 [==============================] - 2s 12ms/step - loss: 0.1948 - mae: 0.3053 - val_loss: 0.1466 - val_mae: 0.2576
# Epoch 43/50
# 176/176 [==============================] - 2s 12ms/step - loss: 0.2083 - mae: 0.3149 - val_loss: 0.2142 - val_mae: 0.2928
# Epoch 44/50
# 176/176 [==============================] - 2s 12ms/step - loss: 0.1965 - mae: 0.3032 - val_loss: 0.1886 - val_mae: 0.2889
# Epoch 45/50
# 176/176 [==============================] - 2s 11ms/step - loss: 0.2034 - mae: 0.3087 - val_loss: 0.1794 - val_mae: 0.2794
# Epoch 46/50
# 176/176 [==============================] - 2s 12ms/step - loss: 0.1890 - mae: 0.2980 - val_loss: 0.1856 - val_mae: 0.2787
# Epoch 47/50
# 176/176 [==============================] - 2s 12ms/step - loss: 0.1834 - mae: 0.2937 - val_loss: 0.2351 - val_mae: 0.3083
# Epoch 48/50
# 176/176 [==============================] - 2s 11ms/step - loss: 0.1842 - mae: 0.2919 - val_loss: 0.2917 - val_mae: 0.3509
# Epoch 49/50
# 176/176 [==============================] - 2s 12ms/step - loss: 0.1809 - mae: 0.2893 - val_loss: 0.1669 - val_mae: 0.2591
# Epoch 50/50
# 176/176 [==============================] - 2s 12ms/step - loss: 0.1890 - mae: 0.2977 - val_loss: 0.2427 - val_mae: 0.3291
# 55/55 [==============================] - 0s 3ms/step

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
def evaluate_model(y_true, y_pred, model_name):
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)

    print(f"\n{model_name} Performance Metrics:")
    print(f"MSE: {mse:.4f}")
    print(f"RMSE: {rmse:.4f}")
    print(f"MAE: {mae:.4f}")
    print(f"R² Score: {r2:.4f}")

    return mse, rmse, mae, r2

results_mlp = evaluate_model(Y_test, Y_pred_mlp, "MLP without Regularization")
results_mlp_reg = evaluate_model(Y_test, Y_pred_mlp_reg, "MLP with Regularization")
results_cnn = evaluate_model(Y_test, Y_pred_cnn.flatten(), "CNN")
# Out:
# MLP without Regularization Performance Metrics:
# MSE: 0.0848
# RMSE: 0.2913
# MAE: 0.1789
# R² Score: 0.8242
#
# MLP with Regularization Performance Metrics:
# MSE: 0.0863
# RMSE: 0.2938
# MAE: 0.1741
# R² Score: 0.8211
#
# CNN Performance Metrics:
# MSE: 0.2208
# RMSE: 0.4699
# MAE: 0.3104
# R² Score: 0.5425

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(9, 12))
plt.subplot(1, 2, 1)

plt.scatter(Y_test, Y_pred_mlp, alpha=0.6, label='MLP', color='blue')
plt.scatter(Y_test, Y_pred_mlp_reg, alpha=0.6, label='MLP with Reg', color='yellow')
plt.scatter(Y_test, Y_pred_cnn, alpha=0.6, label='CNN', color='pink')

plt.plot([Y_test.min(), Y_test.max()], [Y_test.min(), Y_test.max()], 'r--', lw=2, label='Perfect Prediction')

plt.xlabel('Actual Yield', fontsize=12)
plt.ylabel('Predicted Yield', fontsize=12)
plt.title('Actual vs Predicted Crop Yield', fontsize=14)
plt.legend(fontsize=12)

plt.grid(alpha=0.3)
plt.gca().set_aspect('equal', adjustable='box')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('CNN Model Loss During Training')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(alpha=0.3)
min_val_loss_epoch = history.history['val_loss'].index(min(history.history['val_loss']))
plt.scatter(min_val_loss_epoch, min(history.history['val_loss']),
            color='red', label=f'Min Val Loss: {min(history.history["val_loss"]):.4f}', zorder=5)
plt.legend(fontsize=12)
plt.tight_layout()
plt.legend()
plt.show()

# %%
loss_no_reg = mlp_model.loss_curve_
loss_with_reg = mlp_model_reg.loss_curve_

plt.figure(figsize=(10, 6))
plt.plot(loss_no_reg, label='Without Regularization', marker='o')
plt.plot(loss_with_reg, label='With Regularization', marker='s')
plt.xlabel('Iterations')
plt.ylabel('Loss')
plt.title('MLP Training Loss Curve')
plt.legend()
plt.grid(True)
plt.show()

# %%
#apply Random Forest Regressor
from sklearn.ensemble import RandomForestRegressor

rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(X_train, Y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
pred=rf_model.predict(X_test)

# %%
#evaluate the model
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error

mse=mean_squared_error(Y_test,pred)
rmse=np.sqrt(mse)
mae=mean_absolute_error(Y_test,pred)
r2=r2_score(Y_test,pred)

print(mse)
print(rmse)
print(mae)
print(r2)
# Out:
# 0.038106361177501546
# 0.19520850692913347
# 0.10218412813894077
# 0.9210402421614788

# %%
import pandas as pd
from tabulate import tabulate

data = {
    "Model": ["MLP", "MLP + Reg", "CNN",'RandomForestRegressor'],
    "RMSE": [0.2913, 0.2938, 0.4929,0.195],
    "MSE": [0.0848, 0.0863, 0.2430,0.038],
    "MAE": [0.1789, 0.1741, 0.3470,0.102],
    "R² Score": [0.8242, 0.8211, 0.4965,0.921]
}

performance_df = pd.DataFrame(data)

print("Performance Metrics Summary:")
print(tabulate(performance_df, headers="keys", tablefmt="fancy_grid", showindex=False))

hyperparams = {
    "Model": ["MLP", "MLP + Reg", "CNN",'RandomForestRegressor'],
    "Hidden Layers": ["(64, 32)", "(64, 32)", "Conv1D (64, 128)",'N/A'],
    "Alpha (L2 Regularization)": ["0", "0.01", "N/A",'N/A'],
    "Max Iterations / Epochs": [500, 500, "50 Epochs",'N/A'],
    "Early Stopping": ["No", "Yes", "Yes (Patience=5)",'N/A'],
    "Batch Size": ["Default", "Default", "32",'N/A'],
}

hyperparams_df = pd.DataFrame(hyperparams)


print("\nHyperparameter Settings Summary:")
print(tabulate(hyperparams_df, headers="keys", tablefmt="fancy_grid", showindex=False))
# Out:
# Performance Metrics Summary:
# ╒═══════════════════════╤════════╤════════╤════════╤════════════╕
# │ Model                 │   RMSE │    MSE │    MAE │   R² Score │
# ╞═══════════════════════╪════════╪════════╪════════╪════════════╡
# │ MLP                   │ 0.2913 │ 0.0848 │ 0.1789 │     0.8242 │
# ├───────────────────────┼────────┼────────┼────────┼────────────┤
# │ MLP + Reg             │ 0.2938 │ 0.0863 │ 0.1741 │     0.8211 │
# ├───────────────────────┼────────┼────────┼────────┼────────────┤
# │ CNN                   │ 0.4929 │ 0.243  │ 0.347  │     0.4965 │
# ├───────────────────────┼────────┼────────┼────────┼────────────┤
# │ RandomForestRegressor │ 0.195  │ 0.038  │ 0.102  │     0.921  │
# ╘═══════════════════════╧════════╧════════╧════════╧════════════╛
#
# Hyperparameter Settings Summary:
# ╒═══════════════════════╤══════════════════╤═════════════════════════════╤═══════════════════════════╤══════════════════╤══════════════╕
# │ Model                 │ Hidden Layers    │ Alpha (L2 Regularization)   │ Max Iterations / Epochs   │ Early Stopping   │ Batch Size   │
# ╞═══════════════════════╪══════════════════╪═════════════════════════════╪═══════════════════════════╪══════════════════╪══════════════╡
# │ MLP                   │ (64, 32)         │ 0                           │ 500                       │ No               │ Default      │
# ├───────────────────────┼──────────────────┼─────────────────────────────┼───────────────────────────┼──────────────────┼──────────────┤
# │ MLP + Reg             │ (64, 32)         │ 0.01                        │ 500                       │ Yes              │ Default      │
# ├───────────────────────┼──────────────────┼─────────────────────────────┼───────────────────────────┼──────────────────┼──────────────┤
# │ CNN                   │ Conv1D (64, 128) │ N/A                         │ 50 Epochs                 │ Yes (Patience=5) │ 32           │
# ├───────────────────────┼──────────────────┼─────────────────────────────┼───────────────────────────┼──────────────────┼──────────────┤
# │ RandomForestRegressor │ N/A              │ N/A                         │ N/A                       │ N/A              │ N/A          │
# ╘═══════════════════════╧══════════════════╧═════════════════════════════╧═══════════════════════════╧══════════════════╧══════════════╛

# %%
plt.subplot(1, 2, 2)
models = ['MLP', 'MLP+Reg', 'CNN','RandomForest']
rmse_values = [results_mlp[1], results_mlp_reg[1], results_cnn[1],0.195]
r2_values = [results_mlp[3], results_mlp_reg[3], results_cnn[3],0.921]

x = np.arange(len(models))
width = 0.35

plt.bar(x - width/2, rmse_values, width, label='RMSE')
plt.bar(x + width/2, r2_values, width, label='R² Score')
plt.xlabel('Models')
plt.ylabel('Score')
plt.title('Model Performance Comparison')
plt.xticks(x, models)
plt.legend()

plt.tight_layout()
plt.show()

# %%
#save the model random forest regressor
#import pickle
#save
#with open('crop_price_model','wb') as file:
    #pickle.dump(rf_model,file)
